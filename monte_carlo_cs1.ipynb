# %% [markdown]
# # PIDE
# ##### **P**hotovoltaic **I**ntegration **D**ynamics and **E**fficiency for Autonomous Control on Power Distribution Grids
#
# ## **Case Study 1: Sensitivity analysis of mini-photovoltaic integration**
#
# This case study evaluates the sensitivity of various MPV parameters on electric power distribution grids.
# The analysis focuses on:
#
# - **MPV Penetration ($\alpha$)**
# - **MPV Concentration ($\beta$)**
# - **Configurable Apparent Peak Power ($\gamma_1$)**
# - **Configurable Solar Cell Power ($\gamma_2$)**
#
# ### **Execution Workflow**
# 1. **Data Preprocessing**:
#     - Load simulation data from `.csv` files.
#     - Combine and organize data for sensitivity analysis.
# 2. **Sensitivity Analysis**:
#     - Assess the impact of MPV parameters on KPIs such as Voltage Magnitude, Grid Loss, Transformer Loading, and Line Loading.
#     - Visualize results with a 4x4 plot grid.

# %% [markdown]
# ### **(1): Executing Batch Scripts**
# 1. Make the script executable:
#    `chmod +x ./exe_server_master_cs1_job.sh`
# 2. Run the script:
#    `./exe_server_master_cs1_job.sh`
#
# This script executes 20 default Monte Carlo runs and saves the resulting pickle files in the `mcs_results`folder.
# You can modify the `exe_server_master_cs1_job.sh` script directly to adjust the behavior as needed.

# %% [markdown]
# ### **(2): Sensitivity Analysis**
#
# We undertake a comprehensive sensitivity analysis to assess the impacts of **MPV** parameters on the electric power distribution grid. The analysis utilizes a 4x4 plot grid to visualize key performance indicators (KPIs) across various dimensions, providing insights into the influence of MPV characteristics on grid performance.
#
# Key Performance Indicators (KPIs):
#
# - **Voltage Magnitude (VM) in per unit (p.u.)**
# - **Grid Loss (GL) in megawatts (MW)**
# - **Transformer Loading (TL) in percentage (%)**
# - **Line Loading (LL) in percentage (%)**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from helper.notebook_utils import preprocess_data, plot_analysis
# Out:
# /hkfs/home/haicore/iai/ii6824/lp_nlp_env/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))

# %%
# Define directory paths
DIRECTORY_PATH = "./output/notebook/"
output_csv_file_path = "combined_solution.csv"

# Preprocess data
reset_group_dfs, CAPACITIES = preprocess_data(
    directory_path=DIRECTORY_PATH, 
    output_csv_file_path=output_csv_file_path
)

# Sensitivity analysis and plotting
file_name = "fig06_cs1_sensitivity_analysis"
fig, axes = plot_analysis(reset_group_dfs, CAPACITIES, file_name, base_path="./output/mcs_results/")
# Out:
# Loading Simulations Data ID-1 from: ./output/notebook/simulations_data_7_0.0_800_2000.csv
# Loading Simulations Data ID-2 from: ./output/notebook/simulations_data_11_50.0_1000_2000.csv
# Loading Simulations Data ID-3 from: ./output/notebook/simulations_data_3_50.0_600_2000.csv
# Loading Simulations Data ID-4 from: ./output/notebook/simulations_data_8_0.0_1000_800.csv
# Loading Simulations Data ID-5 from: ./output/notebook/simulations_data_5_0.0_800_1200.csv
# Loading Simulations Data ID-6 from: ./output/notebook/simulations_data_8_100.0_1000_800.csv
# Loading Simulations Data ID-38 from: ./output/notebook/simulations_data_1_100.0_600_1200.csv
# Loading Simulations Data ID-39 from: ./output/notebook/simulations_data_11_25.0_1000_2000.csv
# Loading Simulations Data ID-40 from: ./output/notebook/simulations_data_5_50.0_800_1200.csv
# Loading Simulations Data ID-41 from: ./output/notebook/simulations_data_3_25.0_600_2000.csv
# Loading Simulations Data ID-42 from: ./output/notebook/simulations_data_0_75.0_600_800.csv
# Loading Simulations Data ID-43 from: ./output/notebook/simulations_data_11_100.0_1000_2000.csv
# Loading Simulations Data ID-44 from: ./output/notebook/simulations_data_3_75.0_600_2000.csv
# Loading Simulations Data ID-45 from: ./output/notebook/simulations_data_9_75.0_1000_1200.csv
# Loading Simulations Data ID-46 from: ./output/notebook/simulations_data_10_25.0_1000_1600.csv
# Loading Simulations Data ID-47 from: ./output/notebook/simulations_data_6_25.0_800_1600.csv
# Loading Simulations Data ID-48 from: ./output/notebook/simulations_data_0_0.0_600_800.csv
# Loading Simulations Data ID-49 from: ./output/notebook/simulations_data_3_100.0_600_2000.csv
# Loading Simulations Data ID-50 from: ./output/notebook/simulations_data_2_100.0_600_1600.csv
# Loading Simulations Data ID-51 from: ./output/notebook/simulations_data_0_100.0_600_800.csv
# Loading Simulations Data ID-52 from: ./output/notebook/simulations_data_8_75.0_1000_800.csv
# Loading Simulations Data ID-53 from: ./output/notebook/simulations_data_5_25.0_800_1200.csv
# Loading Simulations Data ID-54 from: ./output/notebook/simulations_data_10_50.0_1000_1600.csv
# Loading Simulations Data ID-55 from: ./output/notebook/simulations_data_7_75.0_800_2000.csv
# Loading Simulations Data ID-56 from: ./output/notebook/simulations_data_6_75.0_800_1600.csv
# Loading Simulations Data ID-57 from: ./output/notebook/simulations_data_4_25.0_800_800.csv
# Loading Simulations Data ID-58 from: ./output/notebook/simulations_data_3_0.0_600_2000.csv
# Loading Simulations Data ID-59 from: ./output/notebook/simulations_data_6_50.0_800_1600.csv
# Loading Simulations Data ID-60 from: ./output/notebook/simulations_data_11_0.0_1000_2000.csv
# Saved combined DataFrame at: ./output/notebook/combined_solution.csv
# Group 800: 15 records.
# Saved: 800_capacity.csv
# Group 1200: 15 records.
# Saved: 1200_capacity.csv
# Group 1600: 15 records.
# Saved: 1600_capacity.csv
# Group 2000: 15 records.
# Saved: 2000_capacity.csv
# Group for capacity 800
# Group for capacity 1200
# Group for capacity 1600
# Group for capacity 2000
# Preprocess successful!
# Output: Configuration for half-page plot
# Creating plot with width: 8.26771653543307 inches, height: 4.665354330708661 inches
# The plot has been saved as ./output/mcs_results/fig06_cs1_sensitivity_analysis.pdf

# %%
print("Jupyter Notebook exploration complete. Thank you for your commitment to advancing sustainable energy solutions.")
# Out:
# Jupyter Notebook exploration complete. Thank you for your commitment to advancing sustainable energy solutions.
